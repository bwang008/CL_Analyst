# %%
#this book will be to hash out the replacement for util.py

#get_data should check the data folder for the symbol 'AAPL' for a csv file, if the file exists, pull it if it doesn't exist, then poll yfinance

#The problem with this method right now is that it will not update the newest data, but I will add an option 'forceupdate=True/False' which will grab
# a New file regardless of if it exists

# %%
import pandas as pd
import numpy as np
import yfinance as yf
