# %% [markdown]
# This notebook is used to read dataframe or data from main.py and bring it here to review closer.

# %%
#Import settings specific to this notebook

#Auto reload the main.py notebook or any other module if the code is updated or changed
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Library imports specific to this notebook

import pandas as pd
import numpy as np

# 1. Show ALL columns (removes the horizontal '...')
pd.set_option('display.max_columns', None)

# 2. Show a large number of rows (removes the vertical '...')
# Note: It's safer to set a high number like 500 instead of None 
# so you don't accidentally crash your browser loading millions of rows!
pd.set_option('display.max_rows', 500) 

# 3. (Optional) Prevent text inside individual cells from being truncated
pd.set_option('display.max_colwidth', None)

# %%
#Import modules from parent directory
import sys
import os
from pathlib import Path

# Get the parent directory (CL_Analyst root) and add it to sys.path
# This works regardless of where you run the notebook from
notebook_dir = Path().resolve()  # Current directory
if notebook_dir.name == 'notebooks':
    parent_dir = notebook_dir.parent  # Go up one level to CL_Analyst root
else:
    # If running from root, stay in root
    parent_dir = notebook_dir

# Add parent directory to sys.path for imports
if str(parent_dir) not in sys.path:
    sys.path.insert(0, str(parent_dir))

# Change working directory to project root so relative paths in main.py work correctly
# This ensures 'data/test.csv' resolves to 'CL_Analyst/data/test.csv'
os.chdir(parent_dir)

# Now you can import main
import main

# %%
# get the dataframe from main by calling get_cl_df

#Brings in a dataframe
#data = main.get_cl_df()

#Load a parquet 
dir = r"C:\Users\bwang\Documents\GitHub\CL_Analyst\data\processed\CL_set_06_shortfix.parquet"
data = pd.read_parquet(dir, engine='pyarrow')

# %%
data.head()
# Out:
#                            Open        High         Low       Close  Volume  \
# DateTime
# 2009-01-14 23:45:00  124.746638  124.849905  124.712216  124.849905       6
# 2009-01-14 23:50:00  124.884327  125.262973  124.884327  125.262973      14
# 2009-01-14 23:55:00  125.366240  125.366240  125.194129  125.194129      11
# 2009-01-15 00:00:00  125.194129  125.598633  125.194129  125.425274      18
# 2009-01-15 00:05:00  125.367488  125.454167  125.309701  125.338594       5
#
#                      Time_Sin  Time_Cos   log_ret  VOL_PARK_864  VOL_ROC_864  \
# DateTime
# 2009-01-14 23:45:00 -0.065403  0.997859  0.000000      0.003396    -0.008689
# 2009-01-14 23:50:00 -0.043619  0.999048  0.003303      0.003396    -0.008592
# 2009-01-14 23:55:00 -0.021815  0.999762 -0.000550      0.003396    -0.008586
# 2009-01-15 00:00:00  0.000000  1.000000  0.001845      0.003397    -0.008501
# 2009-01-15 00:05:00  0.021815  0.999762 -0.000691      0.003397    -0.007911
#
# ...

# %%
print("From: ", data['DateTime'].min(), "    To: ", data['DateTime'].max())
# Out:
# From:  2009-01-14 23:45:00     To:  2026-02-15 23:50:00
