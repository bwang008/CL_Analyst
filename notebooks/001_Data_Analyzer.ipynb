# %% [markdown]
# This notebook is used to read dataframe or data from main.py and bring it here to review closer.

# %%
#Import settings specific to this notebook

#Auto reload the main.py notebook or any other module if the code is updated or changed
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Library imports specific to this notebook

import pandas as pd
import numpy as np

# %%
#Import modules from parent directory
import sys
import os
from pathlib import Path

# Get the parent directory (CL_Analyst root) and add it to sys.path
# This works regardless of where you run the notebook from
notebook_dir = Path().resolve()  # Current directory
if notebook_dir.name == 'notebooks':
    parent_dir = notebook_dir.parent  # Go up one level to CL_Analyst root
else:
    # If running from root, stay in root
    parent_dir = notebook_dir

# Add parent directory to sys.path for imports
if str(parent_dir) not in sys.path:
    sys.path.insert(0, str(parent_dir))

# Change working directory to project root so relative paths in main.py work correctly
# This ensures 'data/test.csv' resolves to 'CL_Analyst/data/test.csv'
os.chdir(parent_dir)

# Now you can import main
import main

# %%
# get the dataframe from main by calling get_cl_df

data = main.get_cl_df()
# Out:
# Successfully read data/test10k.csv using separator: ';'

# %%
data
# Out:
#                            Open        High         Low       Close  Volume  \
# DateTime
# 2009-01-07 03:05:00  180.139577  180.325749  179.916171  180.251280     117
# 2009-01-07 03:10:00  180.176811  180.176811  179.283188  179.320422     250
# 2009-01-07 03:15:00  179.283188  179.841703  179.097017  179.730000     171
# 2009-01-07 03:20:00  179.692765  179.804468  179.283188  179.581063      56
# 2009-01-07 03:25:00  179.581063  179.618297  179.357657  179.618297      94
# ...                         ...         ...         ...         ...     ...
# 2009-01-14 00:20:00  145.102094  145.139329  145.027626  145.064860      20
# 2009-01-14 00:25:00  145.139329  145.586140  145.064860  145.586140      40
# 2009-01-14 00:30:00  145.474437  145.958483  145.474437  145.884015      72
# 2009-01-14 00:35:00  145.884015  146.107421  145.735078  146.107421      41
# 2009-01-14 00:40:00  146.032952  146.144655  145.921249  146.070186      19
#
#                            RSI      SMA_20      EMA_20   VOL_24H    VOL_5D  \
# DateTime
# 2009-01-07 03:05:00  53.892113  179.722553  179.948818  0.003318  0.003625
# 2009-01-07 03:10:00  45.231916  179.798883  179.888971  0.003331  0.003627
# 2009-01-07 03:15:00  49.107144  179.867767  179.873831  0.003331  0.003628
# 2009-01-07 03:20:00  47.783123  179.932927  179.845948  0.003322  0.003626
# 2009-01-07 03:25:00  48.159429  179.953406  179.824267  0.003322  0.003624
# ...                        ...         ...         ...       ...       ...
# 2009-01-14 00:20:00  60.796497  144.381610  144.603583  0.003847  0.003313
# 2009-01-14 00:25:00  67.938103  144.489590  144.697160  0.003852  0.003315
# 2009-01-14 00:30:00  71.170038  144.590123  144.810194  0.003829  0.003315
# 2009-01-14 00:35:00  73.340587  144.705549  144.933739  0.003829  0.003315
# 2009-01-14 00:40:00  72.362716  144.817252  145.041972  0.003829  0.003315
#
#                       VOL_30D
# DateTime
# 2009-01-07 03:05:00  0.003614
# 2009-01-07 03:10:00  0.003615
# 2009-01-07 03:15:00  0.003615
# 2009-01-07 03:20:00  0.003615
# 2009-01-07 03:25:00  0.003615
# ...                       ...
# 2009-01-14 00:20:00  0.003636
# 2009-01-14 00:25:00  0.003636
# 2009-01-14 00:30:00  0.003636
# 2009-01-14 00:35:00  0.003636
# 2009-01-14 00:40:00  0.003636
#
# [1360 rows x 11 columns]
